# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-extended-missing-data.csv')

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
# regression
df.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
df.dropna(subset=['Price'], inplace=True)

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [950 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# Make             47
# Colour           46
# Odometer (KM)    48
# Doors            47
# Price             0
# dtype: int64

# %%
X = df.drop('Price', axis=1)
y = df['Price'].copy()

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [950 rows x 5 columns]

# %%
X['Doors'].fillna(X['Doors'].median())      # Replaces NaN with the median
# Out:
# 0      4.0
# 1      5.0
# 2      4.0
# 3      4.0
# 4      3.0
#       ...
# 995    4.0
# 996    3.0
# 997    4.0
# 998    4.0
# 999    4.0
# Name: Doors, Length: 950, dtype: float64

# %%
X['Make'].fillna(value='Missing').value_counts()
# Out:
# Make
# Toyota     354
# Honda      281
# Nissan     175
# BMW         93
# Missing     47
# Name: count, dtype: int64

# %%
X['Make'] = X['Make'].fillna(X['Make'].mode()[0])

# %%
X['Make'].mode()
# Out:
# 0    Toyota
# Name: Make, dtype: object

# %%
X['Colour'] = X['Colour'].fillna(X['Colour'].mode()[0])

# %%
X['Colour'].mode()
# Out:
# 0    White
# Name: Colour, dtype: object

# %%
X.isna().sum()
# Out:
# Make              0
# Colour            0
# Odometer (KM)    48
# Doors             0
# dtype: int64

# %%
X.Make.value_counts()
# Out:
# Make
# Toyota    401
# Honda     281
# Nissan    175
# BMW        93
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal_enc = OrdinalEncoder()

# %%
X['Make_encoded'] = ordinal_enc.fit_transform(pd.DataFrame(X['Make']))

# %%
X
# Out:
#        Make Colour  Odometer (KM)  Doors  Make_encoded
# 0     Honda  White        35431.0    4.0           1.0
# 1       BMW   Blue       192714.0    5.0           0.0
# 2     Honda  White        84714.0    4.0           1.0
# 3    Toyota  White       154365.0    4.0           3.0
# 4    Nissan   Blue       181577.0    3.0           2.0
# ..      ...    ...            ...    ...           ...
# 995  Toyota  Black        35820.0    4.0           3.0
# 996  Toyota  White       155144.0    3.0           3.0
# 997  Nissan   Blue        66604.0    4.0           2.0
# 998   Honda  White       215883.0    4.0           1.0
# 999  Toyota   Blue       248360.0    4.0           3.0
#
# [950 rows x 5 columns]

# %%
X['Colour_encoded'] = ordinal_enc.fit_transform(pd.DataFrame(X['Colour']))

# %%
X
# Out:
#        Make Colour  Odometer (KM)  Doors  Make_encoded  Colour_encoded
# 0     Honda  White        35431.0    4.0           1.0             4.0
# 1       BMW   Blue       192714.0    5.0           0.0             1.0
# 2     Honda  White        84714.0    4.0           1.0             4.0
# 3    Toyota  White       154365.0    4.0           3.0             4.0
# 4    Nissan   Blue       181577.0    3.0           2.0             1.0
# ..      ...    ...            ...    ...           ...             ...
# 995  Toyota  Black        35820.0    4.0           3.0             0.0
# 996  Toyota  White       155144.0    3.0           3.0             4.0
# 997  Nissan   Blue        66604.0    4.0           2.0             1.0
# 998   Honda  White       215883.0    4.0           1.0             4.0
# 999  Toyota   Blue       248360.0    4.0           3.0             1.0
#
# [950 rows x 6 columns]

# %%
X.drop(['Make', 'Colour'], axis=1, inplace=True)

# %%
X
# Out:
#      Odometer (KM)  Doors  Make_encoded  Colour_encoded
# 0          35431.0    4.0           1.0             4.0
# 1         192714.0    5.0           0.0             1.0
# 2          84714.0    4.0           1.0             4.0
# 3         154365.0    4.0           3.0             4.0
# 4         181577.0    3.0           2.0             1.0
# ..             ...    ...           ...             ...
# 995        35820.0    4.0           3.0             0.0
# 996       155144.0    3.0           3.0             4.0
# 997        66604.0    4.0           2.0             1.0
# 998       215883.0    4.0           1.0             4.0
# 999       248360.0    4.0           3.0             1.0
#
# [950 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 rfr.fit(X, y)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
# ...

# %%
rfr.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 rfr.score(X, y)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:759, in RegressorMixin.score(self, X, y, sample_weight)
#     717 """Return the coefficient of determination of the prediction.
#     718
#     719 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     754 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     755 """
#     757 from .metrics import r2_score
# --> 759 y_pred = self.predict(X)
#     760 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:984, in ForestRegressor.predict(self, X)
#     982 check_is_fitted(self)
#     983 # Check data
# --> 984 X = self._validate_X_predict(X)
#     986 # Assign chunk of trees to jobs
# ...

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [950 rows x 5 columns]

# %%
pd.DataFrame(rfr.predict(X), columns=['Price']).concat(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 pd.DataFrame(rfr.predict(X), columns=['Price']).concat(y)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:984, in ForestRegressor.predict(self, X)
#     982 check_is_fitted(self)
#     983 # Check data
# --> 984 X = self._validate_X_predict(X)
#     986 # Assign chunk of trees to jobs
#     987 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:599, in BaseForest._validate_X_predict(self, X)
#     596 """
#     597 Validate X whenever one tries to predict, apply, predict_proba."""
#     598 check_is_fitted(self)
# --> 599 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
# ...
